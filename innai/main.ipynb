# %% [markdown]
# # InnAi

# %%
from InnAiClient.InnAiClient import InnAiClient
import numpy as np
import pandas as pd

# %%
innAiClient = InnAiClient("http://localhost:5294")

# %%
data = np.array(innAiClient.GetData(50))

dataFrame = pd.DataFrame.from_records([x.__dict__ for x in data])
dataFrame
# Out:
#                Timestamp                                          InnLevels  \
# 0   2023-11-15T14:30:00Z  [<InnAiClient.Dtos.InnLevelDto.InnLevelDto obj...
# 1   2023-11-15T14:20:00Z  [<InnAiClient.Dtos.InnLevelDto.InnLevelDto obj...
# 2   2023-11-15T14:10:00Z  [<InnAiClient.Dtos.InnLevelDto.InnLevelDto obj...
# 3   2023-11-15T14:00:00Z  [<InnAiClient.Dtos.InnLevelDto.InnLevelDto obj...
# 4   2023-11-15T13:50:00Z  [<InnAiClient.Dtos.InnLevelDto.InnLevelDto obj...
# 5   2023-11-15T13:40:00Z  [<InnAiClient.Dtos.InnLevelDto.InnLevelDto obj...
# 6   2023-11-15T13:30:00Z  [<InnAiClient.Dtos.InnLevelDto.InnLevelDto obj...
# 7   2023-11-15T13:20:00Z  [<InnAiClient.Dtos.InnLevelDto.InnLevelDto obj...
# 8   2023-11-15T13:10:00Z  [<InnAiClient.Dtos.InnLevelDto.InnLevelDto obj...
# 9   2023-11-15T13:00:00Z  [<InnAiClient.Dtos.InnLevelDto.InnLevelDto obj...
# 10  2023-11-15T12:50:00Z  [<InnAiClient.Dtos.InnLevelDto.InnLevelDto obj...
# ...

# %%
contentId = data[0].ImageId

innAiClient.LoadImageDbz(contentId)
# Out:
# [[-10,
#   -8,
#   -8,
#   -2,
#   -6,
#   -6,
#   -8,
#   3,
#   3,
#   1,
#   -5,
#   -5,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   3,
#   3,
#   -2,
#   -3,
#   -3,
#   -32,
#   -32,
#   -10,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   6,
#   6,
#   6,
#   -5,
#   -5,
#   -32,
#   -32,
#   -32,
#   -6,
#   -6,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -32,
#   -1,
#   -1,
#   -32,
#   -32,
#   -32,
#   -9,
#   17,
#   17,
#   18,
#   25,
#   25,
#   23,
#   23,
#   23,
#   27,
#   28,
#   28,
#   29,
#   25,
#   25,
#   20,
#   20,
#   20,
#   10,
#   9,
#   9,
#   13,
#   13,
#   13,
#   15,
#   20,
#   20,
#   19,
#   9,
#   9,
#   8,
#   8,
#   8,
#   3,
#   3,
#   -32,
# ...
